# %%
from neko.core.network import Network
from neko._visual.visualize_network import NetworkVisualizer
from neko._inputs.resources import Resources
from neko._annotations.gene_ontology import Ontology
import omnipath as op
import pandas as pd

# %% [markdown]
# First set the folder for input and output

# %%
data_folder = "../../../data/"

figures_folder = "../../Figures/WNT/"

sif_output = "../../sif_files/WNT/"

# %% [markdown]
# Selecting as resources just Signor

# %%
resources = Resources()

# %%
resources.import_signor_tsv(data_folder + "signor_db.tsv")

# %% [markdown]
# Loading the data from Antoine

# %%
data = pd.read_csv(data_folder + "gene_per_subgroup_correlation_sorted_melt.csv")

# %%
# Sorting the plot_df by correlation in descending order and selecting the top N genes per group
top_n = 100  # Set the desired number of genes to display per group

top_genes_per_group = data.groupby('Group').apply(lambda x: x.nlargest(top_n, 'Correlation')).reset_index(drop=True)

top_genes_per_group
# Out:
# /tmp/ipykernel_8531/3212156548.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_genes_per_group = data.groupby('Group').apply(lambda x: x.nlargest(top_n, 'Correlation')).reset_index(drop=True)
#          Gene   Group  Correlation
# 0       ZFPM2  Group3     0.957692
# 1       FOXG1  Group3     0.947957
# 2       FSTL5  Group3     0.942308
# 3      PAPPA2  Group3     0.941538
# 4       IMPG2  Group3     0.941538
# ..        ...     ...          ...
# 395     TGIF1     WNT     0.827692
# 396  HSD17B14     WNT     0.826923
# 397    PDGFRA     WNT     0.826923
# 398     SYT14     WNT     0.826154
# 399      ETV6     WNT     0.825385
#
# [400 rows x 3 columns]

# %%
wnt_list = top_genes_per_group[top_genes_per_group["Group"] == "WNT"]["Gene"].reset_index(drop=True).to_list()

# %%
wnt_list
# Out:
# ['ZFPM2',
#  'GALNT14',
#  'LRIG3',
#  'ZIC2',
#  'FAM174B',
#  'RAI2',
#  'APCDD1',
#  'TAL2',
#  'ZIC5',
#  'RBP1',
#  'DSC2',
#  'EVC2',
#  'KCTD17',
#  'ZMAT4',
#  'RTKN',
#  'RASL11B',
#  'LHX8',
#  'SP5',
#  'EMID1',
#  'MEIS1',
#  'GGACT',
#  'SLC24A2',
#  'CDKN1C',
#  'HOXC5',
#  'PRMT8',
#  'HRASLS5',
#  'NRTN',
#  'EVC',
#  'MFNG',
#  'PDGFC',
#  'GAP43',
#  'FBXL7',
#  'HOXD4',
#  'DSP',
#  'PCSK1',
#  'HS3ST1',
#  'HUNK',
#  'EOGT',
#  'HECW1',
#  'GXYLT2',
#  'NKD2',
#  'BMP7',
#  'VRK2',
#  'C18orf42',
#  'TOM1L1',
#  'LRRC55',
#  'SYT1',
#  'SYT2',
#  'PLXDC1',
#  'IL17D',
#  'GALNT12',
#  'SORCS3',
#  'CACNA1A',
#  'ROR2',
#  'KCNK3',
#  'ATP8A1',
#  'RNF112',
#  'NR2F1',
#  'JPH4',
#  'CERS4',
#  'FLRT2',
#  'TGFA',
#  'GADD45A',
#  'IQCA1',
#  'EMX2',
#  'TNFRSF19',
#  'ACKR3',
#  'TMEM132C',
#  'APOL4',
#  'FSTL4',
#  'NRCAM',
#  'TGIF2',
#  'PCYT1B',
#  'S100A2',
#  'VWDE',
#  'CNGA3',
#  'DOK5',
#  'EPHA4',
#  'NBL1',
#  'KCNA2',
#  'HK2',
#  'MYH15',
#  'VWA5B2',
#  'GPR98',
#  'FREM2',
#  'MYO1B',
#  'EFNA5',
#  'NTN1',
#  'TTC9',
#  'SV2A',
#  'TPM1',
#  'IFNLR1',
#  'FRMPD2',
#  'AC092675.3',
#  'SVIL',
#  'TGIF1',
#  'HSD17B14',
#  'PDGFRA',
#  'SYT14',
#  'ETV6']

# %% [markdown]
# # Creating a Network starting from All Omnipath interactions

# %%
wnt_net = Network(wnt_list, resources = resources.interactions)
# Out:
# Error: node GALNT14 is not present in the resources database
# Error: node FAM174B is not present in the resources database
# Error: node RAI2 is not present in the resources database
# Error: node APCDD1 is not present in the resources database
# Error: node ZIC5 is not present in the resources database
# Error: node DSC2 is not present in the resources database
# Error: node EVC2 is not present in the resources database
# Error: node ZMAT4 is not present in the resources database
# Error: node RASL11B is not present in the resources database
# Error: node SP5 is not present in the resources database
# Error: node EMID1 is not present in the resources database
# Error: node GGACT is not present in the resources database
# Error: node HOXC5 is not present in the resources database
# Error: node PRMT8 is not present in the resources database
# Error: node HRASLS5 is not present in the resources database
# Error: node EVC is not present in the resources database
# Error: node HOXD4 is not present in the resources database
# Error: node HS3ST1 is not present in the resources database
# Error: node EOGT is not present in the resources database
# Error: node C18orf42 is not present in the resources database
# Error: node LRRC55 is not present in the resources database
# Error: node PLXDC1 is not present in the resources database
# Error: node IL17D is not present in the resources database
# Error: node GALNT12 is not present in the resources database
# Error: node SORCS3 is not present in the resources database
# Error: node ATP8A1 is not present in the resources database
# Error: node JPH4 is not present in the resources database
# Error: node FLRT2 is not present in the resources database
# Error: node IQCA1 is not present in the resources database
# Error: node TNFRSF19 is not present in the resources database
# Error: node TMEM132C is not present in the resources database
# Error: node APOL4 is not present in the resources database
# Error: node FSTL4 is not present in the resources database
# Error: node TGIF2 is not present in the resources database
# Error: node PCYT1B is not present in the resources database
# Error: node VWDE is not present in the resources database
# Error: node CNGA3 is not present in the resources database
# Error: node NBL1 is not present in the resources database
# Error: node KCNA2 is not present in the resources database
# Error: node MYH15 is not present in the resources database
# Error: node VWA5B2 is not present in the resources database
# Error: node GPR98 is not present in the resources database
# Error: node FREM2 is not present in the resources database
# Error: node MYO1B is not present in the resources database
# Error: node TTC9 is not present in the resources database
# Error: node FRMPD2 is not present in the resources database
# Error: node AC092675.3 is not present in the resources database
# Error: node HSD17B14 is not present in the resources database
# Error: node SYT14 is not present in the resources database

# %% [markdown]
# Adding the node that were not found manually: HOXDB13 --> HOXD13, HOXDB --> HOXD9, Q8N9L1 --> ZIC4

# %%
wnt_net.nodes
# Out:
#    Genesymbol Uniprot Type
# 0       ZFPM2  Q8WW38  NaN
# 1       LRIG3  Q6UXM1  NaN
# 2        ZIC2  O95409  NaN
# 3        TAL2  Q16559  NaN
# 4        RBP1  P09455  NaN
# 5      KCTD17  Q8N5Z5  NaN
# 6        RTKN  Q9BST9  NaN
# 7        LHX8  Q68G74  NaN
# 8       MEIS1  O00470  NaN
# 9     SLC24A2  Q9UI40  NaN
# 10     CDKN1C  P49918  NaN
# 11       NRTN  Q99748  NaN
# 12       MFNG  O00587  NaN
# 13      PDGFC  Q9NRA1  NaN
# 14      GAP43  P17677  NaN
# 15      FBXL7  Q9UJT9  NaN
# 16        DSP  P15924  NaN
# 17      PCSK1  P29120  NaN
# 18       HUNK  P57058  NaN
# 19      HECW1  Q76N89  NaN
# 20     GXYLT2  A0PJZ3  NaN
# 21       NKD2  Q969F2  NaN
# 22       BMP7  P18075  NaN
# 23       VRK2  Q86Y07  NaN
# 24     TOM1L1  O75674  NaN
# 25       SYT1  P21579  NaN
# 26       SYT2  Q8N9I0  NaN
# 27    CACNA1A  O00555  NaN
# 28       ROR2  Q01974  NaN
# 29      KCNK3  O14649  NaN
# 30     RNF112  Q9ULX5  NaN
# 31      NR2F1  P10589  NaN
# 32      CERS4  Q9HA82  NaN
# 33       TGFA  P01135  NaN
# 34    GADD45A  P24522  NaN
# 35       EMX2  Q04743  NaN
# 36      ACKR3  P25106  NaN
# 37      NRCAM  Q92823  NaN
# 38     S100A2  P29034  NaN
# 39       DOK5  Q9P104  NaN
# 40      EPHA4  P54764  NaN
# 41        HK2  P52789  NaN
# 42      EFNA5  P52803  NaN
# 43       NTN1  O95631  NaN
# 44       SV2A  Q7L0J3  NaN
# 45       TPM1  P09493  NaN
# 46     IFNLR1  Q8IU57  NaN
# 47       SVIL  O95425  NaN
# 48      TGIF1  Q15583  NaN
# 49     PDGFRA  P16234  NaN
# 50       ETV6  P41212  NaN

# %%
# %%time
wnt_net.complete_connection(maxlen=4, algorithm="dfs", only_signed=True, connect_with_bias=False, consensus=False)
# Out:
# CPU times: user 2min 15s, sys: 21.7 ms, total: 2min 15s
# Wall time: 2min 15s

# %%
wnt_net.nodes

# %%
wnt_net.edges

# %%
wnt_visualizer = NetworkVisualizer(wnt_net,color_by='effect', noi=True)
output = figures_folder + "WNT_signor_Lin"
wnt_visualizer.render(output_file=output)

# %% [markdown]
# # Exporting Network in sif file

# %% [markdown]
# In order to export a fully connected network in sif file, I remove the nodes that are not connected

# %%
from neko._outputs.exports import Exports

# %%
wnt_net.remove_node("HOXD13")

# %%
wnt_net.remove_node("HOXD9")

# %%
export = Exports(wnt_net)

# %%
export.export_sif(sif_output + "WNT_signor.sif")
